# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b1cf266f-fa65-48d0-ac87-16de1d8fc89e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1cf266f-fa65-48d0-ac87-16de1d8fc89e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# {'cat.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc2\x00\x11\x08\x05@\x06@\x03\x01"BA\xdb\xa1h\xcf\xa4{\x04\xe6h\rv!m\x05\x03\x12\x90\xaa\xeb9Z^\x9c\xcc\xabj\xf3h\xc5\x81\x98\x1e\xf4R\x8bV\xd8\x05\xa1\xc1\x15\x8a%\xca4C\x15.\x15.\x10\x86\xc2\x92\xc9u*\t\x0c\r\x12\xf3e]KBCU%\xd0\xc3\xba]\xb2X\xb8\xca\xa0\xb2\xb8\xab+\xccX\xb0T\x0e\x98\x13c\x126\x8d\x04\x0c"\xaa\x12T\x93\x12I\\\xe1\x1a\x98\x1b\x01\xbd3m[5\x1ck=\xe4\xacl\xb5\x9a\xe5X\x9c\x94\x01\xc0&\x9d,\xcc\x1a\xc12\x0e\x80\x97=4UvUmK\xb6\xad\x8b+43;$u\xa6\xe6^iar\xac\xbb\xabZ\x12\xac\xd2\xba%W?\xa3\xce\x93\x0e\xac\xba\xa5c\x16\xd01\xed\xc5.i$\xb2H\\\x90\x92\xe8;\xa2Q\x13\x02I\nK\x93\x9a:3\xe8\x1d$\xd4\x92B\xe4\x84\xb9\x12\xee\xac\xbb\xab.\xea\xec\xb9!$\x823\xe8\xcf\x9d\x00\x18s\xae\xdb\x8bn\xa6\xd3\x06t\xcdIq$\x95r\xae\xa4\x90\x92B\xea\xe8J\xd8\xb8z\x9a\x93\x16=<\xec\xe8\x10\xc6\xcb\x99\x9b\xf4\x1c\xe7oe\x98Oy\xea)nW\xa7w\xa1\r\x93C\xb371\x89Bst\n\x1d\xa9,J\xc2\xa2\xa9\x95\xa7B12\xa9\xca\x8a`\x1a\xb4\x84\xb7n\xc6kfj-S\x03\x90\x91b\xca\xa9D\x92\xa2]\x94T(\xa3v(v\x05R\x8a\x85\xad\xcb\xcd\x1a\xba\x96\x84\xaa\xa8\xaa\x04b\xd4\x18\xcb\xa5\xd3%\x8b\xbb\xa8\xa9-F\x1c\x00\xee\xe0\xd8\xb0\x99\xd1\xce\xe7\xab\xcf\xddJ\xd2\x1c:\xe2\xe8\xe6\xc9\xac\xfbb\xf2\x9e\xa7\xbf\x94\xa4\xa6(\xc0\xc6\xb1L\xdeM\x88f\xa6\x86%\x9a\x87a(\xc2T\xb5u\x0b\xa3*]\xb4\xaes\x86\x95\x99GH\x19S\xa9\x12\xaa\x8e4\xab+\x02\xce\x88AP\xebU\xc9\xa1\xb9\xdc\x8d 2\xeaKjI\x9aD$\x073\xa7\xcc\x8c\x1a\xf1\xec\x95\xceC\x8a\xc1\xbf\x04\xb9\xa4\x92\xcb\xab$\x90\x97 D$\r\x10\xac\x92\x14\x97\'4^\x87\x8e\x92jK\x90\x92B\xe4\x89wV]\xd5\x97uv\\\x90\xba\x90B4g\xce\x96\x06\x1c\xeb\xf6c\xd9\xa9\xb8\xd6\xce\x99\x92H\x97&\x92HI!$\xb2U\xd0\x95\xb0!\xc9y\x1c\x95\xf74\x1c]\x1di\\\xe6n\x96d\xbdP\xcfo\xb3\x84\x05]\xfa\xdbA\x90|\xbe\x97\x0b\x85\xd3\xab\x1b\xfc\xfd&n\x90Y\x9fV,}q\xe8k\x93\xd4\xeb\xca\x92\xc5L\xa1/T\tTS\xb1\x9b\xa7c5\xb6\x106\xd9rU\t\xc8X\xb4!t\xda\x81\xbb\x85\\\xb9j\x8aP\x11\x12\x0c \x04\rr\x88\x90\xcb*\xe1EE\x16\xd5\xb5.\xeej@hRa\n\xcb\xa2%\x95\xa5\x11r\xf3u\xf2\x89\xbe?B\x94\xc0\xe3\xd4\x96\xeb3\xe6\xe8\xe7N?\xa5\xf3\xcd\xeb\xcf\xd8A.\xde2 \xbb\x18J=Cb\xcfQ\xe6\xa2\xd4e\x01Q\xc9\tp\x828Z\x90\xc4\xac\x15\xb5b\xc1\xa1\x19\xd1\xa5P\x9atTF\xd2\xac^"i\xa3\x0b\x849\x8dz\x1dN02\xea\xe2\xd5]JF\x06/\x9b\xd3\xe6K\xce\xd7\x93\\5\x80\xc8\x98w\xe0k5\xc9,\x92$\xba\xb2I\x03 0D\xc5j]@\xa5\xc9\x94tg\xd0:\xeaj\\\x90\x97V\x92\xea\xc9ue\xddYwWe\xddB\xea\xe8N}\x19\xf3\xa0\x03\x0cWl\xc7\xb2\xcd\xc6\x0c\xe9\x9a\xba\xb2I*I\t$.HIv"\xf5h\x15\xa1\x97`Q\xd5\x81\x0e\x01\n(\xc2\xa4\xa8Q|\xe4]\xf6\xea\xd3Sd.\x0f\x7f\x89\xc3L\xd3\x83\xa1\xe5\xefN\try5\x8d\xcf(v#S\xa5^{\xa3\xd7\x96\xc01\xd70\xa3\x8a\xbb\xb9\xadT\xb9\xad\xb1\xc8n\x8c\x94E\t\x04]YE\t\x885b\\\x1b\n\xaa\xd4\x88JJ\x13\x15Z\xda\xac\x82\x8a\x15.\x89r\xb26%\xd4\xc9/r\xaaU\xa0\x04$:ag1ff\x1c\xf5\xe4\xf4\xeb\xcfS\x96\xee\xd6\x18\xdb\xe6b4\x81\x12s2uy\x1a\x9e\xc7O7\xa7\xeb\xf0\r\x1d\\\xc6\t\xd9f\x17cX\xb6jY\xd1hP\xae\xc1`\x9d\x85r\xec\x84\x06R\xcdp @\xa0\xb2\x08\xbb\xa6\n\xa7KV.\x08@\xb1p\x14u\x04\xe5\xb83\x13$\xb9h\xd5\xd6m\x98\x9a\x873\xa7\xcd\x8ef\xbc\xba\xa1\xcdS\x02\xc1\xbb\x0c\xd6i$I!rBI\x0202\x84\x81d\x90\xa4=9\xa1\xa3>\x81\xd2^\xa4\x92\x12\xea\xd2]Y\n\xac\x97!wWe\xc9\x0b\x92\x84\xe7\xd1\x9f:\x01 \xc5v\xcc{570\x0fy\x92BI*IeK\x84\x96\xe04\xb5\xd6\x01\\*\xae%QP7%T\xb8\xb5.\x15$<\xa1\xac\xfb\xf5kP\xc8n\x1d\x83\x87\x1b\xa9\xc6\xeb\xfc\xff\x00S\x80\x ...

# %%
import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np
import tensorflow as tf

IMAGE_PATH = 'cat.jpg'
LAYER_NAME = 'block5_conv3'
CAT_CLASS_INDEX = 281

img = tf.keras.preprocessing.image.load_img(IMAGE_PATH, target_size=(224, 224))
img = tf.keras.preprocessing.image.img_to_array(img)

model = tf.keras.applications.vgg16.VGG16(weights='imagenet', include_top=True)

grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(LAYER_NAME).output, model.output])

with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(np.array([img]))
    loss = predictions[:, CAT_CLASS_INDEX]

output = conv_outputs[0]
grads = tape.gradient(loss, conv_outputs)[0]

gate_f = tf.cast(output > 0, 'float32')
gate_r = tf.cast(grads > 0, 'float32')
guided_grads = tf.cast(output > 0, 'float32') * tf.cast(grads > 0, 'float32') * grads

weights = tf.reduce_mean(guided_grads, axis=(0, 1))

cam = np.ones(output.shape[0: 2], dtype = np.float32)

for i, w in enumerate(weights):
    cam += w * output[:, :, i]

cam = cv2.resize(cam.numpy(), (224, 224))
cam = np.maximum(cam, 0)
heatmap = (cam - cam.min()) / (cam.max() - cam.min())

cam = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)

output_image = cv2.addWeighted(cv2.cvtColor(img.astype('uint8'), cv2.COLOR_RGB2BGR), 0.5, cam, 1, 0)

cv2.imwrite('cam.png', output_image)
# Out:
# True

# %%
meow = cv2.imread('cat.jpg')
meow = cv2.resize(meow, (224,224))
meow.shape, output_image.shape
# Out:
# ((224, 224, 3), (224, 224, 3))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(meow)
ax2.imshow(output_image)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)
